# %% [markdown]
# <a href="https://colab.research.google.com/github/pedromarinhoabreu44-code/backendpython-test-senai/blob/Feator-fun%C3%A7ao-contagem/aula_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=int(input("mumero: "))
B=int(input ("numero: "))

def calcula(variavela,variavelb):
    print(f"resultado é {variavela+variavelb}")

calcula(A,B)
# Out:
# mumero: 2
# numero: 3
# resultado é 5

# %%
n = int(input("numero: "))

def check(n):
    return 'P' if n > 0 else 'N'
print(check(n))
# Out:
# numero: 12
# P
